# %% [markdown]
# <a href="https://colab.research.google.com/github/RonVest92/Ensemble_Stock_Trading_with-DRL_optimized/blob/main/New_Ensemble_StockTrading_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning (DRL) in Asset Pricing: Ensemble Strategy
#
# ### A task undertaken by Ronald Ddibya utilizing the power of DRL in asset pricing, hence predicting stock market prices.

# %% [markdown]
# # Problem Statement
#
# The project aims to design an automated trading solution for multiple stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the Asset that we have used for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# # Description
#
# * The model uses 5 agent-policies (ppo, ddpg, td3, sac & a2c) to train on in-sample data, then selects the agent with the highest sharpe ratio to predict asset prices on out-of-sample data.
#
# * The model incorporates the trading costs so that we get to understand the exact performance versus risk management. In addition, we also Backtest the strategy with the market benchmark to have a clear performance of the model and probably identify how the performance can be improved.
#
# Our hope is to transfer this model into a production model for live automated trading environment.
# ## Reference
# This TASK is based on FinRL's paper: A Deep Reinforcement Learning Library for Automated Stock Trading in Quantitative Finance, presented at NeurIPS 2020: Deep RL Workshop.

# %% [markdown]
# # Summarry Results
# * The Ensemble Strategy out-performed the market with a sharpe ratio of 1.92 compared to 1.64 as per the benchmark. Our model Annual Returns are significantly higher at 21.12% compared to 18.03% for DJI, with the ensemble strategy having a higher Sortino ratio (3.0774) compared to that of the market (2.4194).

# %% [markdown]
# ###Getting Started- Load Python Packages

# %%
# ## install finrl library
# !pip install wrds
# !pip install swig
# !pip install -q condacolab
import condacolab
condacolab.install()
# !apt-get update -y -qq && apt-get install -y -qq cmake libopenmpi-dev python3-dev zlib1g-dev libgl1-mesa-glx swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# ...
#   Using cached swig-4.2.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (3.6 kB)
# Using cached swig-4.2.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.9 MB)
# ...
# ✨🍰✨ Everything looks OK!
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# ...
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /tmp/pip-req-build-_nnud6s5
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git /tmp/pip-req-build-_nnud6s5
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit e523ca0519288b3117f014e19163fe4c514d20ea
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !pip install --upgrade stable_baselines3
# !pip install numpy==1.23.5
# !pip install yahoo-finance-api
# !pip install matplotlib
# !pip install stockstats
# !pip install gym-toytext
# !pip install tensorflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 90.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# wrds 3.2.0 requires numpy<1.27,>=1.26, but you have numpy 1.23.5 which is incompatible.
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 58.6 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Installing build dependencies ... error
# error: subprocess-exited-with-error
#
# ...

# %%
# !pip uninstall pyfolio
# !pip install git+https://github.com/stefan-jansen/pyfolio-reloaded.git
# Out:
# Found existing installation: pyfolio 0.9.2
# Uninstalling pyfolio-0.9.2:
#   Would remove:
#     /usr/local/lib/python3.10/site-packages/pyfolio-0.9.2.dist-info/*
#     /usr/local/lib/python3.10/site-packages/pyfolio/*
# Proceed (Y/n)? Y
#   Successfully uninstalled pyfolio-0.9.2
# ...
#   Cloning https://github.com/stefan-jansen/pyfolio-reloaded.git to /tmp/pip-req-build-wp08kpev
#   Running command git clone --filter=blob:none --quiet https://github.com/stefan-jansen/pyfolio-reloaded.git /tmp/pip-req-build-wp08kpev
#   Resolved https://github.com/stefan-jansen/pyfolio-reloaded.git to commit a013587528a92f0f091f27d34b532430fa859558
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 41.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %% [markdown]
# ###Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime
from pyfolio import timeseries

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from finrl.main import check_and_make_directories
from stable_baselines3.common.logger import configure
from finrl.meta.data_processor import DataProcessor
from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# ###Download Data

# %%
print(DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
# TRAIN_START_DATE = '2009-04-01'
# TRAIN_END_DATE = '2021-01-01'
# TEST_START_DATE = '2021-01-01'
# TEST_END_DATE = '2022-06-01'

TRAIN_START_DATE = '2009-01-01'
TRAIN_END_DATE = '2023-04-01'
TEST_START_DATE = '2023-04-01'
TEST_END_DATE = '2024-10-17'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
df.head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2009-01-02   3.067143   3.251429   3.041429   2.737005  746015200  AAPL
# 1  2009-01-02  58.590000  59.080002  57.750000  41.816154    6547900  AMGN
# 2  2009-01-02  18.570000  19.520000  18.400000  15.014076   10955700   AXP
# 3  2009-01-02  42.799999  45.560001  42.779999  33.941093    7010200    BA
# 4  2009-01-02  44.910000  46.980000  44.709999  30.712524    7117200   CAT
#
#    day
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4

# %%
df.tail()
# Out:
#               date        open        high         low       close    volume  \
# 116646  2024-10-16  557.010010  576.179993  555.119995  571.340027   5103900
# 116647  2024-10-16  278.619995  287.600006  278.350006  287.519989   9442700
# 116648  2024-10-16   43.740002   44.099998   43.660000   43.910000   9459000
# 116649  2024-10-16   10.470000   11.110000   10.250000   11.070000  49804600
# 116650  2024-10-16   81.529999   81.660004   80.620003   81.220001  11123300
#
#         tic  day
# 116646  UNH    2
# 116647    V    2
# 116648   VZ    2
# 116649  WBA    2
# 116650  WMT    2

# %%
df.shape
# Out:
# (116651, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2009-01-02   3.067143   3.251429   3.041429   2.737005  746015200  AAPL
# 1  2009-01-02  58.590000  59.080002  57.750000  41.816154    6547900  AMGN
# 2  2009-01-02  18.570000  19.520000  18.400000  15.014076   10955700   AXP
# 3  2009-01-02  42.799999  45.560001  42.779999  33.941093    7010200    BA
# 4  2009-01-02  44.910000  46.980000  44.709999  30.712524    7117200   CAT
#
#    day
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4

# %%
len(df.tic.unique())
# Out:
# 30

# %%
df.tic.value_counts()
# Out:
# tic
# AAPL    3974
# AMGN    3974
# AXP     3974
# BA      3974
# CAT     3974
# CRM     3974
# CSCO    3974
# CVX     3974
# DIS     3974
# GS      3974
# HD      3974
# HON     3974
# IBM     3974
# INTC    3974
# JNJ     3974
# JPM     3974
# KO      3974
# MCD     3974
# MMM     3974
# MRK     3974
# MSFT    3974
# NKE     3974
# PG      3974
# TRV     3974
# UNH     3974
# V       3974
# VZ      3974
# WBA     3974
# WMT     3974
# DOW     1405
# Name: count, dtype: int64

# %% [markdown]
# ###Preprocess Data

# %%
INDICATORS
# Out:
# ['macd',
#  'boll_ub',
#  'boll_lb',
#  'rsi_30',
#  'cci_30',
#  'dx_30',
#  'close_30_sma',
#  'close_60_sma']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.sample(5)
# Out:
#               date        open        high         low       close     volume  \
# 110366  2024-02-15  107.019997  107.339996  105.830002  104.793671    7201300
# 112213  2024-05-17  168.970001  169.110001  167.330002  167.564438    2956400
# 76223   2019-06-13  173.570007  173.589996  172.330002  155.381378    1400700
# 4424    2009-08-11   24.709999   24.740000   24.475000   15.314482   12509000
# 4756    2009-08-27    6.026786    6.056071    5.886786    5.110584  449181600
#
#          tic  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 110366   NKE    3  0.029140  105.966716   97.542496  50.827988  160.282785
# 112213   IBM    4 -3.172490  178.263368  156.048972  43.312590  -46.333388
# 76223    HON    3  1.299709  156.250359  146.298013  61.407812  127.428112
# 4424      KO    1  0.040319   15.885219   15.151906  53.347395  -28.324904
# 4756    AAPL    3  0.119475    5.155590    4.848487  64.733104   82.568063
#
# ...

# %%
processed.to_csv("processed.csv")

# %% [markdown]
# ###Design Environment

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "buy_cost_pct": 0.001,
    "sell_cost_pct": 0.001,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4,
    "print_verbosity":5

}

# %% [markdown]
# ###Implement DRL Algorithms

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window,
                 validation_window=validation_window,
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      "action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 100000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

SAC_model_kwargs = {
    "batch_size": 64,
    "buffer_size": 100000,
    "learning_rate": 0.001,
    "learning_starts": 0.001,
    "ent_coef": "auto_0.1",
    "target_entropy": "auto"
}

TD3_model_kwargs = {"batch_size": 100, "buffer_size": 1000000, "learning_rate": 0.0001, "target_policy_noise": 0.2, "target_noise_clip": 0.5}




timesteps_dict = {'a2c' : 10_000,
                 'ppo' : 10_000,
                 'ddpg' : 10_000,
                 'sac' : 10_000,
                 'td3' : 10_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 SAC_model_kwargs,
                                                 TD3_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ...
# turbulence_threshold:  200.93033481315283
# ======Model training from:  2009-01-01 to  2023-04-03
# ======a2c Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_126_1
# --------------------------------------
# | time/                 |            |
# |    fps                | 65         |
# |    iterations         | 100        |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.301     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -42        |
# |    reward             | 0.13854313 |
# |    std                | 1          |
# |    value_loss         | 0.991      |
# --------------------------------------
# --------------------------------------
# ...

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe  \
# 0  126  2023-04-03  2023-07-05        PPO   0.086435   0.245336   -0.023863
# 1  189  2023-07-05  2023-10-03       DDPG  -0.515086  -0.338963   -0.067515
# 2  252  2023-10-03  2024-01-03       DDPG   0.513382   0.337011    0.697565
# 3  315  2024-01-03  2024-04-04       DDPG   0.047165   0.015324     0.34988
# 4  378  2024-04-04  2024-07-05       DDPG   -0.10276  -0.118214    0.276863
#
#   SAC Sharpe TD3 Sharpe
# 0   0.213201   0.196651
# 1  -0.082777  -0.197466
# 2   0.469094   0.555361
# 3   0.263694   0.210015
# 4   0.110723   0.191297

# %% [markdown]
# ###Backtest Our Strategy

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

# Initialize an empty DataFrame
df_account_value = pd.DataFrame()

# Loop through the range and check for file existence
for i in range(rebalance_window + validation_window, len(unique_trade_date) + 1, rebalance_window):
    file_path = 'results/account_value_trade_{}_{}.csv'.format('ensemble', i)
    if os.path.exists(file_path):
        temp = pd.read_csv(file_path)
        df_account_value = pd.concat([df_account_value, temp], ignore_index=True)
    else:
        print(f"File not found: {file_path}")


# df_account_value=pd.DataFrame()
# for i in range(rebalance_window + validation_window, len(unique_trade_date)+1,rebalance_window):
#     temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
#     df_account_value = pd.concat([df_account_value, temp], ignore_index=True)


sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
print(df_account_value)
# Out:
# Sharpe Ratio:  1.915622026968887
#      account_value        date  daily_return    datadate
# 0     1.000000e+06  2023-07-05           NaN  2023-07-05
# 1     9.992180e+05  2023-07-06     -0.000782  2023-07-06
# 2     9.993005e+05  2023-07-07      0.000083  2023-07-07
# 3     1.000934e+06  2023-07-10      0.001634  2023-07-10
# 4     1.002649e+06  2023-07-11      0.001714  2023-07-11
# ..             ...         ...           ...         ...
# 310   1.266331e+06  2024-09-26      0.008633  2024-09-26
# 311   1.272140e+06  2024-09-27      0.004587  2024-09-27
# 312   1.273940e+06  2024-09-30      0.001415  2024-09-30
# 313   1.267966e+06  2024-10-01     -0.004689  2024-10-01
# 314   1.270594e+06  2024-10-02      0.002072  2024-10-02
#
# [315 rows x 4 columns]

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   1.000000e+06  2023-07-05           NaN  2023-07-05
# 1   9.992180e+05  2023-07-06     -0.000782  2023-07-06
# 2   9.993005e+05  2023-07-07      0.000083  2023-07-07
# 3   1.000934e+06  2023-07-10      0.001634  2023-07-10
# 4   1.002649e+06  2023-07-11      0.001714  2023-07-11

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <Axes: >

# %% [markdown]
# ###BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return          0.211171
# Cumulative returns     0.270594
# Annual volatility      0.103130
# Sharpe ratio           1.915622
# Calmar ratio           2.660760
# Stability              0.808200
# Max drawdown          -0.079365
# Omega ratio            1.391477
# Sortino ratio          3.077442
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.050093
# Daily value at risk   -0.012209
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
df_dji_ = get_baseline(
        ticker="^DJI",
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(df_dji_, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (314, 8)
# Annual return          0.180331
# Cumulative returns     0.229473
# Annual volatility      0.104493
# Sharpe ratio           1.644362
# Calmar ratio           1.999733
# Stability              0.828613
# Max drawdown          -0.090178
# Omega ratio            1.311372
# Sortino ratio          2.419395
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.067203
# Daily value at risk   -0.012483
# dtype: float64

# %%
df_dji = pd.DataFrame()
df_dji['date'] = df_account_value['date']
df_dji['dji'] = df_dji_['close'] / df_dji_['close'][0] * env_kwargs["initial_amount"]
print("df_dji: ", df_dji)
df_dji.to_csv("df_dji.csv")
df_dji = df_dji.set_index(df_dji.columns[0])
print("df_dji: ", df_dji)
df_dji.to_csv("df_dji+.csv")

df_account_value.to_csv('df_account_value.csv')
# Out:
# df_dji:             date           dji
# 0    2023-07-05  1.000000e+06
# 1    2023-07-06  9.893149e+05
# 2    2023-07-07  9.838500e+05
# 3    2023-07-10  9.899605e+05
# 4    2023-07-11  9.992062e+05
# ..          ...           ...
# 310  2024-09-26  1.230002e+06
# 311  2024-09-27  1.234024e+06
# 312  2024-09-30  1.234524e+06
# 313  2024-10-01  1.229473e+06
# 314  2024-10-02           NaN
#
# [315 rows x 2 columns]
# df_dji:                       dji
# date
# 2023-07-05  1.000000e+06
# 2023-07-06  9.893149e+05
# 2023-07-07  9.838500e+05
# 2023-07-10  9.899605e+05
# 2023-07-11  9.992062e+05
# ...                  ...
# 2024-09-26  1.230002e+06
# 2024-09-27  1.234024e+06
# 2024-09-30  1.234524e+06
# 2024-10-01  1.229473e+06
# 2024-10-02           NaN
#
# [315 rows x 1 columns]

# %% [markdown]
# ###BackTestPlot

# %%
# print("==============Compare to DJIA===========")
# %matplotlib inline
# # S&P 500: ^GSPC
# # Dow Jones Index: ^DJI
# # NASDAQ 100: ^NDX
# backtest_plot(df_account_value,
#               baseline_ticker = '^DJI',
#               baseline_start = df_account_value.loc[0,'date'],
#               baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
df.to_csv("df.csv")
df_result_ensemble = pd.DataFrame({'date': df_account_value['date'], 'ensemble': df_account_value['account_value']})
df_result_ensemble = df_result_ensemble.set_index('date')

print("df_result_ensemble.columns: ", df_result_ensemble.columns)

# df_result_ensemble.drop(df_result_ensemble.columns[0], axis = 1)
print("df_trade_date: ", df_trade_date)
# df_result_ensemble['date'] = df_trade_date['datadate']
# df_result_ensemble['account_value'] = df_account_value['account_value']
df_result_ensemble.to_csv("df_result_ensemble.csv")
print("df_result_ensemble: ", df_result_ensemble)
print("==============Compare to DJIA===========")
result = pd.DataFrame()
# result = pd.merge(result, df_result_ensemble, left_index=True, right_index=True)
# result = pd.merge(result, df_dji, left_index=True, right_index=True)
result = pd.merge(df_result_ensemble, df_dji, left_index=True, right_index=True)
print("result: ", result)
result.to_csv("result.csv")
result.columns = ['ensemble', 'dji']

# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
result.plot();
# Out:
# df_result_ensemble.columns:  Index(['ensemble'], dtype='object')
# df_trade_date:         datadate
# 0    2023-04-03
# 1    2023-04-04
# 2    2023-04-05
# 3    2023-04-06
# 4    2023-04-10
# ..          ...
# 383  2024-10-10
# 384  2024-10-11
# 385  2024-10-14
# 386  2024-10-15
# 387  2024-10-16
#
# [388 rows x 1 columns]
# df_result_ensemble:                  ensemble
# date
# 2023-07-05  1.000000e+06
# 2023-07-06  9.992180e+05
# 2023-07-07  9.993005e+05
# 2023-07-10  1.000934e+06
# 2023-07-11  1.002649e+06
# ...                  ...
# 2024-09-26  1.266331e+06
# 2024-09-27  1.272140e+06
# 2024-09-30  1.273940e+06
# 2024-10-01  1.267966e+06
# 2024-10-02  1.270594e+06
#
# [315 rows x 1 columns]
# ==============Compare to DJIA===========
# result:                  ensemble           dji
# date
# 2023-07-05  1.000000e+06  1.000000e+06
# 2023-07-06  9.992180e+05  9.893149e+05
# 2023-07-07  9.993005e+05  9.838500e+05
# 2023-07-10  1.000934e+06  9.899605e+05
# ...
